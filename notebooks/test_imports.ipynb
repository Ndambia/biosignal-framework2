# %%
import os
import sys

# Add parent directory to Python path
project_root = os.path.dirname(os.path.dirname(os.path.abspath(os.getcwd())))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f'Python path: {sys.path}')

from preprocessing import SignalDenoising
import numpy as np

# Create test data
data = np.random.randn(1000)

# Create denoiser
denoiser = SignalDenoising()

# Test filtering
filtered = denoiser.bandpass_filter(data, lowcut=1, highcut=40, fs=100)

print('Successfully imported and used SignalDenoising')
